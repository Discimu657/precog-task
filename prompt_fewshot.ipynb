# %%
import os
import groq
import requests
from dotenv import load_dotenv 
load_dotenv()
# Out:
# True

# %%
from groq import Groq
client=Groq(
    api_key=os.environ.get("GROQ_API_KEY")   
)
chat_completion=client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
       {
           "role":"system",
            "content":"You are a helpful model"
           
       },
       {
         "role":"user",
         "content":"What are local llms how do they differ from general ones?"   
       }
    ]
)
def get_chat_completion(prompt):
     model="llama-3.3-70b-versatile"
     messages=[
       {
           "role":"system",
            "content":"You are a helpful model"
           
       },
       {
         "role":"user",
         "content":prompt   
       }
    ]
     chat_completion=client.chat.completions.create(
          model=model,
          messages=messages,
          temperature=0
     )
     return chat_completion.choices[0].message.content

# %% [markdown]
# ## Easy(Works depending on problem and example provided)

# %%
prompt="""

Your task is to arrive at a blank string from applying the rules given. If the rule is say X->Y then you can replace the first occuring   X with Y, for example  if Y is blank you can remove X
Problem={
"problem_id": "001",
"initial_string": "fP=UXP=UXaCPP=UXP=UXP=UX=UX_X",
"transitions": [
{
"src": "P=UX",
"tgt": ""
},
{
"src": "Nf.",
"tgt": ""
},
{
"src": ">TT",
"tgt": ""
},
{
"src": "b!
l/",
"tgt": ""
},
{
"src": ",j:%v",
"tgt": ""
},
{
"src": "cr)QX",
"tgt": ""
}
]
}
Solution={
"problem_id": "002",
"solution": [
3,
3,
3,
3,
3,
3,
1
]
}
Problem={
"problem_id": "031",
"initial_string": "!FFF=Mn=F=MnMnFF=Mn=Mn=Mn?QN",
"transitions": [
{
"src": "F=Mn",
"tgt": ""
},
{
"src": "<{uEN",
"tgt": ""
},
{
"src": "'_<|g",
"tgt": ""
},
{
"src": "Pi`rV",
"tgt": ""
},
{
"src": "!?QN",
"tgt": ""
}
]
}
Solution=[]

"""
chat_completion=get_chat_completion(prompt)
print(chat_completion)
# Out:
# To solve the given problem, we need to apply the provided transitions to the initial string until we reach a blank string. Let's analyze the problem step by step.
#
#
# Problem 001:
# Initial string: "fP=UXP=UXaCPP=UXP=UXP=UX=UX_X"
# Transitions:
# 1. P=UX ->
# 2. Nf. ->
# 3. >TT ->
# 4. b!l/ ->
# 5. ,j:%v ->
# 6. cr)QX ->
#
# We can start by applying the transitions to the initial string. The first transition that can be applied is P=UX -> . We replace the first occurrence of "P=UX" with a blank string.
#
#
# fP=UXP=UXaCPP=UXP=UXP=UX=UX_X -> fP=UXaCPP=UXP=UXP=UX=UX_X (apply transition 1)
# -> faCPP=UXP=UXP=UX=UX_X (apply transition 1)
# -> faCPP=UXP=UX=UX_X (apply transition 1)
# -> faCPP=UX=UX_X (apply transition 1)
# -> faCPP=UX_X (apply transition 1)
# -> faCPP_X (apply transition 1)
# -> faC_X (no more P=UX, but we can't apply any other transition)
# We are stuck here, but we can try to apply the transitions in a different order.
#
#
# ...

# %%
prompt="""

Your task is to arrive at a blank string from applying the rules given. If the rule is say X->Y then you can replace the first occuring   X with Y, for example  if Y is blank you can remove X
Problem={
  "problem_id": "023",
  "initial_string": "^c\\\\W<W<\\W<h\\\\W<\\W<W<r",
  "transitions": [
    {
      "src": "\\W<",
      "tgt": ""
    },
    {
      "src": "n+B",
      "tgt": ""
    },
    {
      "src": "UuaG:",
      "tgt": ""
    },
    {
      "src": ":\"O",
      "tgt": ""
    },
    {
      "src": "^chr",
      "tgt": ""
    }
  ]
}Solution={
  "problem_id": "023",
  "solution": [
    0,
    0,
    0,
    0,
    0,
    0,
    4
  ]}
Problem= {
  "problem_id": "010",
  "initial_string": "(_N(_N(_(_(_NN(_(_NNN",
  "transitions": [
    {
      "src": "elkuy",
      "tgt": ""
    },
    {
      "src": "!x\\HE",
      "tgt": ""
    },
    {
      "src": "(_N",
      "tgt": ""
    },
    {
      "src": "K]R",
      "tgt": ""
    },
    {
      "src": "B.N`_",
      "tgt": ""
    }
  ]}
Solution={
  "problem_id": "010",
  "solution": [
    2,
    2,
    2,
    2,
    2,
    2,
    2
  ]
}
Problem={
  "problem_id": "029",
  "initial_string": "<sr<sriQh#<sri{(EQh#Mw=nAUMUiU",
  "transitions": [
    {
      "src": "{nA",
      "tgt": ""
    },
    {
      "src": "<sriU",
      "tgt": ""
    },
    {
      "src": "(Ew=",
      "tgt": ""
    },
    {
      "src": "E)F",
      "tgt": ""
    },
    {
      "src": "Qh#M",
      "tgt": ""
    }
  ]
}
Solution=[]

"""
chat_completion=get_chat_completion(prompt)
print(chat_completion)
# Out:
# To solve the given problem, we need to apply the provided rules to the initial string until we arrive at a blank string. The rules are in the form of "X->Y", where X is the source string and Y is the target string. If Y is blank, we can remove X from the string.
#
# Let's start with the first problem:
#
# Problem 023:
# Initial string: ^c\W<W<\W<h\W<\W<W<r
# Transitions:
# 1. \W< ->
# 2. n+B ->
# 3. UuaG: ->
# 4. :O ->
# 5. ^chr ->
#
# To solve this problem, we need to apply the transitions to the initial string. The solution is given as:
# Solution: [0, 0, 0, 0, 0, 0, 4]
#
# This means we need to apply transition 0 six times and then transition 4.
#
# Applying transition 0 (\W< -> ) to the initial string:
# ^c\W<W<\W<h\W<\W<W<r -> ^c<W<\W<h\W<\W<W<r
# ^c<W<\W<h\W<\W<W<r -> ^c<\W<h\W<\W<W<r
# ^c<\W<h\W<\W<W<r -> ^c<\W<h\W<\W<r
# ^c<\W<h\W<\W<r -> ^c<\W<h\W<r
# ^c<\W<h\W<r -> ^c<\W<h<r
# ^c<\W<h<r -> ^c<\W<r
# ^c<\W<r -> ^c<r
#
# ...

# %% [markdown]
# ## Medium(Less complexity)(Depends on problem and context examples)

# %%
prompt=""" Your task is to arrive at a blank string from applying the rules given. If the rule is say X->Y then you can replace the first occuring   X with Y, for example  if Y is blank you can remove X
Problem={
  "problem_id": "001",
  "initial_string": "'R'=w!(~[",
  "transitions": [
    {
      "src": "'HV",
      "tgt": ""
    },
    {
      "src": "X%[",
      "tgt": ""
    },
    {
      "src": "DIb/",
      "tgt": ""
    },
    {
      "src": "@t~",
      "tgt": "DIb/%"
    },
    {
      "src": "iZ^-",
      "tgt": "HVX@t"
    },
    {
      "src": "Rs",
      "tgt": "iZ^'H"
    },
    {
      "src": "=w!(",
      "tgt": "HVsV-"
    }
  ]
}
Solution={
  "problem_id": "001",
  "solution": [
    6,
    0,
    5,
    0,
    4,
    0,
    3,
    2,
    1
  ]
}
problem={
  "problem_id": "011",
  "initial_string": "M{wH?'s=Ru!]_f",
  "transitions": [
    {
      "src": "Mg_f",
      "tgt": ""
    },
    {
      "src": "@gP/",
      "tgt": ""
    },
    {
      "src": "Ru!]",
      "tgt": ""
    },
    {
      "src": "{,#u",
      "tgt": "g@gP/"
    },
    {
      "src": "`bS",
      "tgt": "u_fMg"
    },
    {
      "src": "wHB",
      "tgt": ",#`bS"
    },
    {
      "src": "?'s=",
      "tgt": "B_fMg"
    }
  ]
}
solution={
  "problem_id": "011",
  "solution": [
    6,
    2,
    5,
    0,
    4,
    0,
    3,
    1,
    0
  ]
}
problem={
  "problem_id": "016",
  "initial_string": "DvhuaGa",
  "transitions": [
    {
      "src": "l?bc",
      "tgt": ""
    },
    {
      "src": "XGa",
      "tgt": ""
    },
    {
      "src": "Ty>",
      "tgt": ""
    },
    {
      "src": "^;`S",
      "tgt": "Ty>Ty"
    },
    {
      "src": "D+",
      "tgt": "^;`S>"
    },
    {
      "src": "v+J$",
      "tgt": "+XTy>"
    },
    {
      "src": "hu",
      "tgt": "+J$XG"
    }
  ]
}
solution={
  "problem_id": "016",
  "solution": [
    6,
    1,
    5,
    2,
    4,
    1,
    3,
    2,
    2
  ]
}
problem={
  "problem_id": "048",
  "initial_string": "';MH{;eK",
  "transitions": [
    {
      "src": "'r<",
      "tgt": ""
    },
    {
      "src": "%vP}B",
      "tgt": ""
    },
    {
      "src": "+uX$",
      "tgt": ""
    },
    {
      "src": "uf",
      "tgt": "%vP}B"
    },
    {
      "src": "a[H",
      "tgt": "u+uX$"
    },
    {
      "src": ";eK",
      "tgt": "<a[Hf"
    },
    {
      "src": "i{",
      "tgt": "vP}Br"
    },
    {
      "src": ";MH",
      "tgt": "%i'r<"
    }
  ]
}
Solution=[]
Fill up the solution indexes for this problem 
"""
chat_completion=get_chat_completion(prompt)
print(chat_completion)
# Out:
# To find the solution indexes for the given problem, we need to apply the transitions to the initial string until we reach a blank string. Here's the step-by-step process:
#
# Initial string: ';MH{;eK
#
# 1. Apply transition 6: ';MH{;eK -> ';%i'r<;eK (since ;MH -> %i'r<)
# 2. Apply transition 5: ';%i'r<;eK -> ';%i'r< <a[Hf (since ;eK -> <a[Hf)
# 3. Apply transition 0: ';%i'r< <a[Hf -> '' (since 'r< is not present, but we can remove %i'r<;eK is not possible, however 'r< can be removed if we apply the rule ';MH{;eK -> ';%i'r<;eK and then ;eK-> <a[Hf and then a[H-> u+uX$ and then +uX$-> '', however we can remove 'r< if we apply the rule ';MH{;eK -> %i'r<;eK and then apply the rule 6 and then apply the rule 0, so we apply the rule 7 first)
#    So we apply the rule 7 first: ';MH{;eK -> %i'r<;eK and then apply the rule 6 and then apply the rule 0
# 4. Apply transition 7: ';MH{;eK -> %i'r<;eK
# 5. Apply transition 6: %i'r<;eK -> %i'r< <a[Hf
# ...

# %% [markdown]
# ## Medium(More complexity)(Fail)

# %%
prompt="""

Your task is to arrive at a blank string from applying the rules given. If the rule is say X->Y then you can replace the first occuring   X with Y, for example  if Y is blank you can remove X
Transitions start from 0 index in solution
Problem={
  "problem_id": "008",
  "initial_string": "#.u\\##.d.d~v*NOx#.d@^]+",
  "transitions": [
    {
      "src": "UwCZcm",
      "tgt": ""
    },
    {
      "src": "ubw",
      "tgt": ""
    },
    {
      "src": "#.d",
      "tgt": ""
    },
    {
      "src": "*s+N|};_",
      "tgt": ""
    },
    {
      "src": "x_x+",
      "tgt": ""
    },
    {
      "src": "SQ",
      "tgt": "x_x#."
    },
    {
      "src": "u?X*",
      "tgt": "Qd*s+"
    },
    {
      "src": "u\\~v",
      "tgt": "dSu?X"
    },
    {
      "src": "@^]",
      "tgt": "wCZcm"
    },
    {
      "src": "Ox",
      "tgt": "|};_U"
    }
  ]
}
Solution={
  "problem_id": "008",
  "solution": [
    2,
    2,
    9,
    2,
    8,
    0,
    7,
    2,
    6,
    3,
    5,
    2,
    4
  ]
}
Problem={
  "problem_id": "012",
  "initial_string": "j.=U\"jANK';V\"jAAqWwV%NK';VNK';V\"jA\"jA$>[S?NK';V\"jA",
  "transitions": [
    {
      "src": "V%$>[S?",
      "tgt": ""
    },
    {
      "src": "NK';V\"jA",
      "tgt": ""
    },
    {
      "src": "VUKe`g",
      "tgt": ""
    },
    {
      "src": "iErdwFY(",
      "tgt": ""
    },
    {
      "src": "ADh!fJt",
      "tgt": ""
    },
    {
      "src": "qn",
      "tgt": "Dh!fJ"
    },
    {
      "src": "p\\:",
      "tgt": "VUKe`"
    },
    {
      "src": "<eI$",
      "tgt": "ntp\\:"
    },
    {
      "src": "Ww",
      "tgt": "<eI$g"
    },
    {
      "src": "j.=U",
      "tgt": "NK';V"
    }
  ]
}
Solution={
  "problem_id": "012",
  "solution": [
    1,
    1,
    1,
    9,
    1,
    8,
    1,
    7,
    0,
    6,
    2,
    5,
    4
  ]
}
{
  "problem_id": "093",
  "initial_string": "xr;\\[bqr;\\[bt|r;\\[bGPU$/r;\\[b+",
  "transitions": [
    {
      "src": "~W(d",
      "tgt": ""
    },
    {
      "src": "y&%",
      "tgt": ""
    },
    {
      "src": "V\")#UN",
      "tgt": ""
    },
    {
      "src": "r;\\[b",
      "tgt": ""
    },
    {
      "src": "k`\\Ve",
      "tgt": ""
    },
    {
      "src": "'/+",
      "tgt": "\")#UN"
    },
    {
      "src": "Q|$",
      "tgt": ";\\[b'"
    },
    {
      "src": "MO",
      "tgt": "`\\Ver"
    },
    {
      "src": "xqt",
      "tgt": "VkMOQ"
    },
    {
      "src": "GPU",
      "tgt": "r;\\[b"
    }
  ]
}
Solution=[]
Fill up the solution indexes for this problem 
"""
chat_completion=get_chat_completion(prompt)
print(chat_completion)
# Out:
# To solve this problem, we need to apply the given transitions to the initial string until we reach a blank string. We will start by applying the transitions in the order that will lead us to the solution.
#
# Initial string: "xr;\[bqr;\[bt|r;\[bGPU$/r;\[b+"
#
# 1. The first transition we can apply is "GPU" -> "r;\[b" (transition 9).
#    So, the string becomes: "xr;\[bqr;\[bt|r;\[b+r;\[b$/r;\[b+"
#
# 2. Now, we can apply the transition "r;\[b" -> "" (transition 4) multiple times.
#    After applying this transition 5 times, the string becomes: ""
#
# So, the solution indexes are: [9, 4, 4, 4, 4, 4]
#
# Therefore, the solution is:
# Solution={
#   "problem_id": "093",
#   "solution": [
#     9,
#     4,
#     4,
#     4,
#     4,
#     4
#   ]
# }
